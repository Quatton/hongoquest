# %% [markdown]
# # 初心者向けプログラミング レポート
#
# ダブルクリックすると編集できます。
#
# 科類:
#
# クラス:
#
# 氏名:
#
# 学籍番号:

# %% [markdown]
# ## 3.1.1 平方根の計算プログラム
# x = 「1z」(10～19の範囲の値)の平方根を求めるpythonのプログラムを作成し， 求められた値と計算の回数(反復した回数)を示しなさい。ただし、以下のようにすること。
#
# z部分には学生証番号末尾の数字をあてるものとする。たとえば、学生証番号が「J4210001」であれば、11の平方根を求めることになる。
#
# 教科書で示された 「反復による計算」「二分法による計算」 「ニュートン・ラフソン法による計算」の 3通りのプログラムを作成し、それぞれの結果と示すものとする。ただし「ニュートン・ラフソン法による計算」は 選択課題として、余裕のある者だけで良い。
#
# - deltaの値としては 0.001 を用いること。 教科書では 0.0001 となっているので注意しなさい。
# - 反復による計算では、最初のyの値を 0.0 としなさい。
# - 二分法による計算では、最初の区間(aとb)の値を a = 0, b = x(= 「1z」)としなさい。
# - ニュートン・ラフソン法による計算では、最初のyの値をx(= 「1z」)としなさい。

# %% [markdown]
# ####(ヒント)
# 下をクリックすると表示されます。

# %% [markdown]
# 計算回数をカウントする変数を使うと便利であり、以下に載せている各アルゴリズムを実行するプログラムを改変すると良いでしょう。

# %%
# 反復による平方根の計算
x = 2.0
delta = 0.0001
y = 0.0

while (y+delta)*(y+delta) < x:
  #print(y)
  y = y + delta
print(y)
# Out:
# 1.4141999999998607

# %%
# 二分法による平方根の計算
x = 2.0
delta = 0.0001
a = 0.0
b = x

while (b-a) > delta:
  #print(str(a)+" "+str(b))
  c = (a+b)/2
  if c*c > x:
    b = c
  else:
    a = c
print(a)
# Out:
# 1.4141845703125

# %%
#ニュートン・ラフソン法による平方根の計算
x = 2.0
delta = 0.0001
y = x

while abs(x-y*y) / (2.0*y) > delta: #abs(hoge)とすると、hogeの絶対値が得られる。
  #print(str(y) + " " + str(abs(y-y*y) / (2.0*y)))
  y = (y*y + x) / (2.0*y)
print(y)
# Out:
# 1.4142156862745099

# %% [markdown]
# ### アルゴリズム1 反復による平方根の計算

# %% [markdown]
# 求められた値:
#
# 計算の回数:

# %% [markdown]
# ### アルゴリズム2 二分法による平方根の計算

# %% [markdown]
# 求められた値:
#
# 計算の回数:

# %% [markdown]
# ### アルゴリズム3 ニュートン・ラフソン法による平方根の計算

# %% [markdown]
# 求められた値:
#
# 計算の回数:

# %% [markdown]
# ## 3.1.2 発展課題
# 余裕のある人は次の発展課題にも取り組んでみましょう。
#
# 上記で求めた値の平方根と同じ値の立方根を求めるプログラムを書いて提出しなさい(11の平方根を求めたのであれば11の立方根を求める)。
#
# ただし立方根を求める際には、プログラムの応用で示したプログラムの式を変更しなければならない点に注意しなさい。

# %% [markdown]
# アルゴリズム1 反復による平方根の計算

# %% [markdown]
# 求められた値:
#
# 計算の回数:

# %% [markdown]
# アルゴリズム2 二分法による平方根の計算

# %% [markdown]
# 求められた値:
#
# 計算の回数:

# %% [markdown]
# アルゴリズム3 ニュートン・ラフソン法による平方根の計算

# %% [markdown]
# 求められた値:
#
# 計算の回数:

# %% [markdown]
# ## 3.2.1 タートルグラフィックス
# タートルグラフィックスによって正n角形を描く関数、`draw_regular_polygon(n)`を完成させなさい。ただし、以下のようにすること
#
#
# *   一辺の長さは50とすること。
# *   `draw_regular_polygon`を完成させたら、正z角形を描画しなさい。ただし、z部分には学生証番号末尾の数字+3をあてるものとする。たとえば、学生証番号が「J4210001」であれば、正方形を描画する。
#
# 正三角形，正方形，正六角形は、一種類で平面充填が可能な図形として知られている。この三つの図形のいずれかを選んで平面を充填したものをタートルグラフィックスで描写しなさい。

# %%
### turtleライブラリを使用するため、最初に実行すること ###
# !pip install ColabTurtle
import ColabTurtle.Turtle as turtle
turtle.initializeTurtle()
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.0.0-cp37-none-any.whl size=4032 sha256=90cb8ba44183bc5ee1d0c08337046d523da6262666a7ef41bb73f9dc958e06f5
#   Stored in directory: /root/.cache/pip/wheels/a8/29/ec/ad346f0042ae467cc74f4378916348faf975b07890651dcae7
# Successfully built ColabTurtle
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#
#       <g visibility=visible transform="rotate(180,400,250) translate(400, 250)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# ####(ヒント)

# %% [markdown]
# `draw_regular_polygon`には以下に載せる正三角形を描画するプログラムが参考になるでしょう。

# %%
# 正三角形を描画するプログラム
turtle.pendown()
for i in range(3):
    turtle.forward(100) #前に100進む
    turtle.right(120) #右に1２０°回転する
turtle.penup()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="486.6025403784439" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="486.6025403784439" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# 平面充填を行う際には、`draw_regular_polygon`を繰り返し利用することを考えましょう。その際、カメの位置や向きなどに気をつけて利用しましょう。また、下では画面全体を充填している例を載せていますが、必ずしも全面を充填しなくても問題ありません。難しければ一部だけ充填してみましょう。

# %% [markdown]
# ### 正n角形を描く関数

# %%
def draw_regular_polygon(n):
  turtle.pendown()
  ### ここを埋めてください ###
  turtle.penup()

# %%
# zを学生証番号末尾の数字+3に置き換えてください。
turtle.initializeTurtle()
draw_regular_polygon(z)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="443.30127018922195" y2="225.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="443.30127018922195" y1="225.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180.0,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
# draw_regular_polygonを利用して、正三角形or正方形or正六角形を平面充填する
turtle.initializeTurtle()
turtle.speed(10) #スピードを変更する関数。描くのに時間がかかるので、カメを速くしておく
turtle.penup()
turtle.goto(0, 50) #画面の左上にカメを移動させる。

### 以下を埋める ###
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# ## 3.2.2 発展課題
# 余裕のある人は次の課題にも取り組んでみましょう。
#
# 平面充填可能な図形は他にも知られている。正多角形以外の図形を描く関数を作り、3.2.1と同様に平面充填をしなさい。平面充填可能な図形については[このwikipediaのページ](https://ja.wikipedia.org/wiki/平面充填)などを参照しても良い。

# %%
def draw_tiling_polygon():
  ### 平面充填可能な図形を描く関数を定義する。 ###

# %%
turtle.initializeTurtle()
turtle.speed(10) #スピードを変更する関数。描くのに時間がかかるので、カメを速くしておく
turtle.penup()
turtle.goto(0, 50) #画面の左上にカメを移動させる。

### 以下に平面充填を行うプログラムを書く ###

# %% [markdown]
# 授業で難しいと感じたこと/再度説明して欲しいところなど：

# %% [markdown]
# その他、授業に関する感想：
